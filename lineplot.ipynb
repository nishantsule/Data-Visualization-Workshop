# %% [markdown]
# #### Import relevant python packages

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #### Jupyter Notebook Magic command to make matplotlib figures show inline

# %%
# %matplotlib notebook

# %% [markdown]
# #### Read data from file and view the variable names

# %%
data = np.load('historicalQuotes_AAPLvsIBM.npz', encoding='bytes')
data.files
# Out:
# ['AAPLcp',
#  'AAPLhp',
#  'AAPLlp',
#  'AAPLop',
#  'AAPLt',
#  'AAPLvol',
#  'IBMcp',
#  'IBMhp',
#  'IBMlp',
#  'IBMop',
#  'IBMt',
#  'IBMvol']

# %% [markdown]
# #### Load the variables into arrays

# %%
AAPLcp = data['AAPLcp']
AAPLhp = data['AAPLhp']
AAPLlp = data['AAPLlp']
AAPLop = data['AAPLop']
AAPLt = data['AAPLt']
AAPLvol = data['AAPLvol']
IBMcp = data['IBMcp']
IBMhp = data['IBMhp']
IBMlp = data['IBMlp']
IBMop = data['IBMop']
IBMt = data['IBMt']
IBMvol = data['IBMvol']

# %% [markdown]
# #### Convert the time data to datetime format to matplotlib dates format

# %%
import datetime as dtime
import matplotlib.dates as dt

AAPLtnew = np.empty(len(AAPLt))
for i in range(0, len(AAPLt)):
    dto = dtime.datetime.strptime(AAPLt[i], '%d-%b-%Y')
    AAPLtnew[i] = dt.date2num(dto)
AAPLt = AAPLtnew
IBMtnew = np.empty(len(IBMt))
for i in range(0, len(IBMt)):
    dto = dtime.datetime.strptime(IBMt[i], '%d-%b-%Y')
    IBMtnew[i] = dt.date2num(dto)
IBMt = IBMtnew

# %% [markdown]
# #### Plot data

# %%
fig1 = plt.figure()
ax1 = fig1.add_subplot(111)
ax1.plot(dt.num2date(AAPLt), AAPLcp)
fig1.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# #### Add other data and modify axes and line properties
# link to the xkcd color survey: https://xkcd.com/color/rgb/

# %%
fig2 = plt.figure()
ax2 = fig2.add_subplot(111)
ax2.plot(dt.num2date(AAPLt), AAPLcp, color='xkcd:sky blue', label='AAPL')
ax2.plot(dt.num2date(IBMt), IBMcp, color='xkcd:salmon', label="IBM")
ax2.set_xlabel('Date')
ax2.set_ylabel('Closing Price')
ax2.legend()
fig2.autofmt_xdate()
fig2.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# #### Change date range on the x axis

# %%
datemin = dt.date2num(dtime.datetime.strptime('2017-05-01', '%Y-%m-%d'))
datemax = dt.date2num(dtime.datetime.strptime('2017-10-30', '%Y-%m-%d'))

# %% [markdown]
# #### Add lines for high/low prices

# %%
fig3 = plt.figure()
ax3 = fig3.add_subplot(111)
ax3.plot(dt.num2date(AAPLt), AAPLcp, color='xkcd:sky blue', label='AAPL')
ax3.plot(dt.num2date(IBMt), IBMcp, color='xkcd:salmon', label="IBM")
ax3.plot(dt.num2date(AAPLt), AAPLhp, color='xkcd:sky blue', linewidth=0.5)
ax3.plot(dt.num2date(AAPLt), AAPLlp, color='xkcd:sky blue', linewidth=0.5)
ax3.plot(dt.num2date(IBMt), IBMhp, color='xkcd:salmon', linewidth=0.5)
ax3.plot(dt.num2date(IBMt), IBMlp, color='xkcd:salmon', linewidth=0.5)
ax3.set_xlabel('Date')
ax3.set_ylabel('Closing Price')
ax3.set_xlim(dt.num2date(datemin), dt.num2date(datemax))
ax3.set_ylim(135, 170)
dfmt = dt.DateFormatter('%b')
ax3.xaxis.set_major_formatter(dfmt)
ax3.legend()
ax3.legend(frameon=False)
fig3.autofmt_xdate()
fig3.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# #### Zoom in on July, change line style, and add markers

# %%
datemin = dt.date2num(dtime.datetime.strptime('2017-07-01', '%Y-%m-%d'))
datemax = dt.date2num(dtime.datetime.strptime('2017-07-31', '%Y-%m-%d'))
fig4 = plt.figure()
ax4 = fig4.add_subplot(111)
ax4.plot(dt.num2date(AAPLt), AAPLcp, color='xkcd:sky blue', linestyle=':', marker='o', label='AAPL')
ax4.plot(dt.num2date(IBMt), IBMcp, color='xkcd:salmon', linestyle=':', marker='d', label="IBM")
ax4.plot(dt.num2date(AAPLt), AAPLhp, color='xkcd:sky blue', linewidth=0.5)
ax4.plot(dt.num2date(AAPLt), AAPLlp, color='xkcd:sky blue', linewidth=0.5)
ax4.plot(dt.num2date(IBMt), IBMhp, color='xkcd:salmon', linewidth=0.5)
ax4.plot(dt.num2date(IBMt), IBMlp, color='xkcd:salmon', linewidth=0.5)
ax4.set_xlabel('Date')
ax4.set_ylabel('Closing Price')
ax4.set_xlim(dt.num2date(datemin), dt.num2date(datemax))
ax4.set_ylim(142, 158)
dfmt = dt.DateFormatter('%d-%b')
ax4.xaxis.set_major_formatter(dfmt)
ax4.legend()
ax4.legend(frameon=False)
fig4.autofmt_xdate()
fig4.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
